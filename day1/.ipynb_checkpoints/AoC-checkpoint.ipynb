# %%
with open('input.txt') as f:
    data = f.readlines()
    data.splitlines()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7f5b8e90c786> in <module>
#       1 with open('input.txt') as f:
#       2     data = f.readlines()
# ----> 3     data.splitlines()
#
# AttributeError: 'list' object has no attribute 'splitlines'

# %%
lines
# Out:
# ['5229\n',
#  '1021\n',
#  '2051\n',
#  '4766\n',
#  '2272\n',
#  '5810\n',
#  '4688\n',
#  '2324\n',
#  '2108\n',
#  '1555\n',
#  '1221\n',
#  '4146\n',
#  '5044\n',
#  '2238\n',
#  '4504\n',
#  '\n',
#  '4800\n',
#  '3333\n',
#  '1171\n',
#  '5362\n',
#  '6213\n',
#  '3200\n',
#  '1185\n',
#  '5839\n',
#  '4075\n',
#  '3956\n',
#  '6688\n',
#  '4293\n',
#  '2244\n',
#  '\n',
#  '6719\n',
#  '2596\n',
#  '5233\n',
#  '5371\n',
#  '4802\n',
#  '5901\n',
#  '6093\n',
#  '2420\n',
#  '2593\n',
#  '4093\n',
#  '1909\n',
#  '3851\n',
#  '4143\n',
#  '\n',
#  '4353\n',
#  '6425\n',
#  '2546\n',
#  '6368\n',
#  '1939\n',
#  '8550\n',
#  '10505\n',
#  '4718\n',
#  '\n',
#  '16579\n',
#  '11333\n',
#  '\n',
#  '15453\n',
#  '15172\n',
#  '2678\n',
#  '9202\n',
#  '12549\n',
#  '\n',
#  '2133\n',
#  '16769\n',
#  '6807\n',
#  '10384\n',
#  '\n',
#  '5130\n',
#  '\n',
#  '5492\n',
#  '2088\n',
#  '4364\n',
#  '2038\n',
#  '4419\n',
#  '7450\n',
#  '3359\n',
#  '6575\n',
#  '1811\n',
# ...
